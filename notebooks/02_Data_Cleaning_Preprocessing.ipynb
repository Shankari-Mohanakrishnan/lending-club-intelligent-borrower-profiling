# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',100)

# %%
data=pd.read_csv('../data/loan.csv', low_memory=False)
data.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade       emp_title emp_length  \
# 0     13.56        84.92     C        C1            Chef  10+ years
# 1     18.94       777.23     D        D2     Postmaster   10+ years
# 2     17.97       180.69     D        D1  Administrative    6 years
# 3     18.94       146.51     D        D2   IT Supervisor  10+ years
# 4     16.14       731.78     C        C4        Mechanic  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
data.shape
# Out:
# (2260668, 145)

# %%
## Target variable

# %%
data['loan_status'].unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (31-120 days)', 'In Grace Period',
#        'Charged Off', 'Late (16-30 days)', 'Default',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
good_status = ['Does not meet the credit policy. Status:Fully Paid','Fully Paid']
bad_status = ['In Grace Period', 'Does not meet the credit policy. Status:Charged Off','Late (31-120 days)','Late (16-30 days)','Charged Off', 'Default']
df = data[data['loan_status'].isin(good_status + bad_status)].copy()
print(f'Shape before keeping  only good & bad statuses: {data.shape}')
print(f'Shape after keeping  only good & bad statuses: {df.shape}')
df.head()
# Out:
# Shape before keeping  only good & bad statuses: (2260668, 145)
# Shape after keeping  only good & bad statuses: (1340973, 145)
#      id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 100 NaN        NaN      30000        30000          30000.0   36 months
# 152 NaN        NaN      40000        40000          40000.0   60 months
# 170 NaN        NaN      20000        20000          20000.0   36 months
# 186 NaN        NaN       4500         4500           4500.0   36 months
# 215 NaN        NaN       8425         8425           8425.0   36 months
#
#      int_rate  installment grade sub_grade  \
# 100     22.35      1151.16     D        D5
# 152     16.14       975.71     C        C4
# 170      7.56       622.68     A        A3
# 186     11.31       147.99     B        B3
# 215     27.27       345.18     E        E5
#
#                                 emp_title emp_length home_ownership  \
# 100                           Supervisor     5 years       MORTGAGE
# ...

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Late (31-120 days)', 'In Grace Period',
#        'Charged Off', 'Late (16-30 days)', 'Default',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %% [markdown]
# Current staus is removed as we are considering only good (completed pay back) and bad (not paying regularly).

# %%
df['default_flag']=np.where(df['loan_status'].isin(bad_status),1,0)
df.head()
# Out:
#      id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 100 NaN        NaN      30000        30000          30000.0   36 months
# 152 NaN        NaN      40000        40000          40000.0   60 months
# 170 NaN        NaN      20000        20000          20000.0   36 months
# 186 NaN        NaN       4500         4500           4500.0   36 months
# 215 NaN        NaN       8425         8425           8425.0   36 months
#
#      int_rate  installment grade sub_grade  \
# 100     22.35      1151.16     D        D5
# 152     16.14       975.71     C        C4
# 170      7.56       622.68     A        A3
# 186     11.31       147.99     B        B3
# 215     27.27       345.18     E        E5
#
#                                 emp_title emp_length home_ownership  \
# 100                           Supervisor     5 years       MORTGAGE
# 152  Assistant to the Treasurer (Payroll)   < 1 year       MORTGAGE
# ...

# %%
df['default_flag'].value_counts()
# Out:
# default_flag
# 0    1043940
# 1     297033
# Name: count, dtype: int64

# %%
df['default_flag'].value_counts(normalize=True)*100
# Out:
# default_flag
# 0    77.849442
# 1    22.150558
# Name: proportion, dtype: float64

# %% [markdown]
# 22% of data is in bad status (charge off, default, not paid) and 77% in good status (paid back).

# %% [markdown]
# ## Dropping columns having more than 50% missing columns

# %%
missing_percent = df.isnull().mean()*100
cols_to_drop = missing_percent[missing_percent>50].index.to_list()
print(f'Number of columns that have more than 50% data missing {len(cols_to_drop)}')
print("\n\nThe columns are:")
print(cols_to_drop)
df = df.drop(columns=cols_to_drop)
print(f'\n\nThe shape after dropping the coumns: {df.shape}')
# Out:
# Number of columns that have more than 50% data missing 58
#
#
# The columns are:
# ...

# %% [markdown]
# ## Dropping IDs, text and leakage columns

# %%
cols_to_drop_manual = [
    "id",
    "member_id",
    "url",
    "desc",
    "title",
    "zip_code",
    "loan_status",
    "pymnt_plan",
    "policy_code"
]

cols_to_drop_manual = [cols for cols in cols_to_drop_manual if cols in df.columns]
df = df.drop(columns=cols_to_drop_manual)
print(f'Shape after dropping IDs, text & target leakage columns {df.shape}')
# Out:
# Shape after dropping IDs, text & target leakage columns (1340973, 83)

# %% [markdown]
# ## Checking for remaining missing values

# %%
missing_summary = df.isnull().sum().to_frame('missing_count')\
            .assign(missing_percent = lambda x: (x['missing_count']/len(df))*100)\
            .sort_values('missing_percent', ascending=False)

missing_summary.head(30)
# Out:
#                             missing_count  missing_percent
# mths_since_recent_inq              175271        13.070435
# num_tl_120dpd_2m                   120430         8.980792
# mo_sin_old_il_acct                 108244         8.072049
# emp_title                           85929         6.407959
# emp_length                          78428         5.848589
# pct_tl_nvr_dlq                      70430         5.252156
# avg_cur_bal                         70299         5.242387
# mo_sin_old_rev_tl_op                70277         5.240747
# mo_sin_rcnt_rev_tl_op               70277         5.240747
# num_rev_accts                       70277         5.240747
# num_tl_30dpd                        70276         5.240672
# num_tl_90g_dpd_24m                  70276         5.240672
# num_actv_bc_tl                      70276         5.240672
# num_op_rev_tl                       70276         5.240672
# num_tl_op_past_12m                  70276         5.240672
# ...

# %%
df.head()
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 100      30000        30000          30000.0   36 months     22.35
# 152      40000        40000          40000.0   60 months     16.14
# 170      20000        20000          20000.0   36 months      7.56
# 186       4500         4500           4500.0   36 months     11.31
# 215       8425         8425           8425.0   36 months     27.27
#
#      installment grade sub_grade                             emp_title  \
# 100      1151.16     D        D5                           Supervisor
# 152       975.71     C        C4  Assistant to the Treasurer (Payroll)
# 170       622.68     A        A3                               Teacher
# 186       147.99     B        B3                 Accounts Examiner III
# 215       345.18     E        E5       Senior Director Risk Management
#
#     emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.to_pickle('../data/lending_club_clean_base.pkl')
